# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([0,1,2,3,1,1.5])
Y = np.array([1,2,1.5,2,1,2])

plt.scatter(X,Y)

coeff = np.polyfit(X,Y,2)

a2 = coeff[0]
a1 = coeff[1]
a0 = coeff[2]

x = np.linspace(0,10,100)
plt.scatter(X,Y)
plt.plot(x,np.power(x,2)*a2 + x*a1 + a0)

Y_pred = np.power(X,2)*a2 + X*a1 + a0
print(Y_pred)

sum_square_error = 0

for i in range(len(Y)):
  sum_square_error += (Y[i] - Y_pred[i])**2

print(sum_square_error)
# Out:
# [1.02824561 1.51578947 1.81736842 1.93298246 1.51578947 1.68982456]
# 0.7027192982456141
